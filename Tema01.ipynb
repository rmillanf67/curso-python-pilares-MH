# %% [markdown]
# ## Variables

# %% [markdown]
# Consta de un espacio en memoria y un nombre simbolico

# %%
numero = 7

# %%
palabra = "Hola Mundo"

# %%
print("Escuela de Codigo")
print(numero)
print(palabra)
# Out:
# Escuela de Codigo
# 7
# Hola Mundo

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
nombreMascota = "Firulais"

# %%
NombreMascota = "Toby"

# %%
nombre_mascota = "Toby"

# %%
x = 5
x + 1
# Out:
# 6

# %%
x = x + 1
print(x)
# Out:
# 7

# %% [markdown]
# ## Comentarios

# %%
# Esto es un comentario

# %%
""" Este es un comentario de varias líneas"""
# Out:
# ' Este es un comentario de varias líneas'

# %% [markdown]
# ## Funcion import

# %%
import math as mt

# %%
mt.factorial(5)
# Out:
# 120

# %% [markdown]
# ## Números en Python

# %% [markdown]
# - int: número entero
# - float: número en coma flotante

# %%
numero = 7

# %%
type(numero)
# Out:
# int

# %%
numero = 5.8
type(numero)
# Out:
# float

# %%
numero = int(5.8)
type(numero)
# Out:
# int

# %% [markdown]
# ## Operaciones aritmeticas

# %%
numero1 = 7
numero2 = 5.8

# %%
# SUMA
suma = numero1 + numero2
print(suma)
# Out:
# 12.8

# %%
# Resta
resta = numero1 - numero2
print(resta)
# Out:
# 1.2000000000000002

# %%
# Division
division = numero1 / numero2
print(division)
# Out:
# 1.206896551724138

# %%
# Multiplicacion
multiplicacion = numero1 * numero2
print(multiplicacion)
# Out:
# 40.6

# %%
# Modulo
modulo = numero1 % numero2
print(modulo)
# Out:
# 1.2000000000000002

# %%
# Potencia
potencia = numero2 ** numero1
print(potencia)
# Out:
# 220798.41675519996

# %%
# Division entera
division_entera = numero1 // numero2
print(division_entera)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Division entera
# ----> 2 division_entera = numero1 // numero2
#       3 print(division_entera)
#
# NameError: name 'numero1' is not defined
