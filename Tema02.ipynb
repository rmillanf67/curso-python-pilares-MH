# %% [markdown]
# ## Strings

# %%
s1 = "Bievenido al curso de Python"
type(s1)
# Out:
# str

# %%
s2 = 'Bienvenido al curso de Python'
type(s2)
# Out:
# str
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Strings literales

# %% [markdown]
# s1 = "Ignacio dijo: \"me gusta la programacion\""
# s1

# %%
s1 = "Ignacio dijo: \"me gusta la programacion\""
s1
# Out:
# 'Ignacio dijo: "me gusta la programacion"'

# %%
s1 = "Ignacio dijo: me gusta la programacion y es muy divertido \t  gusta aprender cosas nuevas"
s1
# Out:
# 'Ignacio dijo: me gusta la programacion y es muy divertido \t  gusta aprender cosas nuevas'

# %%
print(s1)
# Out:
# Ignacio dijo: me gusta la programacion y es muy divertido 	  gusta aprender cosas nuevas

# %% [markdown]
# ## Concatenación de Strings

# %%
s1 = "Juan"
s2 = "Gonzalez"
s3 = " "
s4 = s1 + s3 + s2

# %%
print(s4)
# Out:
# Juan Gonzalez

# %%
s1 = "Hola Mundo " 
s2 = s1 * 3
print(s2)
# Out:
# Hola Mundo Hola Mundo Hola Mundo

# %%
nombre = "Luis"
print("Hola " + nombre + "!")
# Out:
# Hola Luis!

# %%
numero = 10
print("La edad de Miguelito es: " + str(numero) + " años")
# Out:
# La edad de Miguelito es: 10 años

# %% [markdown]
# ### Ejercicio 2:
# Realizar de la siguiente frase una repeticion de 2 veces y ademas, guardar tres enunciados y concatenarlos:
#
#
# El éxito es la suma de pequeños esfuerzos repetidos día tras día. — Robert Collier

# %% [markdown]
# ### Función format

# %%
nombre = "Alheli"
curso = "Python"
print("La estudiante {} esta tomando el curso de {}".format(nombre, curso))
# Out:
# La estudiante Alheli esta tomando el curso de Python

# %% [markdown]
# ### Ejercicio 3
# De las siguientes variables realiza una frase coherente con la funcion .format().
#
#
# s1 = "Computadora"
#
#
# s2 = "Carlos"
#
#
#
# s3 = "Pizza"

# %% [markdown]
# ## Substrings

# %%
s = "Soy fan de los videojuegos"
s1 = s[0:7]
s2 = s[7:14]
s3 = s[14:26]
print(s1 + s2 + s3)
print(s3+s2+s1)
# Out:
# Soy fan de los videojuegos
#  videojuegos de losSoy fan

# %%
s[0]
# Out:
# 'S'

# %%
s[-1]
# Out:
# 's'

# %%
s[0:7]
# Out:
# 'Soy fan'

# %% [markdown]
# ### Ejercicio 4:
#
#
# De la siguiente frase crear 3 substrings y posteriormente concatenarlos de forma inversa:
#
#
# El pesimista ve la dificultad en cada oportunidad. El optimista ve la oportunidad en cada dificultad

# %% [markdown]
# ## Métodos para strings

# %%
s = "Me ENCANTAN el chocolate y las galletas"
s.lower()
# Out:
# 'me encantan el chocolate y las galletas'

# %%
s.upper()
# Out:
# 'ME ENCANTAN EL CHOCOLATE Y LAS GALLETAS'

# %%
s = s.lower()
s.count("a")
# Out:
# 6

# %%
s.capitalize()
# Out:
# 'Me encantan el chocolate y las galletas'

# %%
s.title()
# Out:
# 'Me Encantan El Chocolate Y Las Galletas'

# %%
s.swapcase()
# Out:
# 'mE encantan EL CHOCOLATE Y LAS GALLETAS'

# %%
s = "panditas rojos"
s.replace("rojos","verdes")
# Out:
# 'panditas verdes'

# %%
s = "Python es un lenguaje de programacion muy popular"
s.split("e")
# Out:
# ['Python ', 's un l', 'nguaj', ' d', ' programacion muy popular']

# %%
s = "Python es un lenguaje de programacion muy popular"
s.split(" ")
# Out:
# ['Python', 'es', 'un', 'lenguaje', 'de', 'programacion', 'muy', 'popular']

# %%
s = "             Python es un lenguaje de programacion muy popular"
s.strip()
# Out:
# 'Python es un lenguaje de programacion muy popular'

# %%
s = "Python es un lenguaje de programacion muy popular              "
s.rstrip()
# Out:
# 'Python es un lenguaje de programacion muy popular'

# %%
s.find("Python")
# Out:
# 0

# %%
s.find("e", 8,40)
# Out:
# 14

# %%
s.index("lenguaje")
# Out:
# 13

# %%
len(s)
# Out:
# 63

# %% [markdown]
# ## Input()

# %%
print("Ingresa un numero: ")
numero = input()
# Out:
# Ingresa un numero:

# %%
print(numero)
# Out:
# 10

# %%
numero = input("Introduce un numero: ")

# %%
print(numero)
# Out:
# 45
